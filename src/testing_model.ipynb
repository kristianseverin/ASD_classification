# %%
# !pip install simpletransformers  # force install simpletransformers into colab environment
import pandas as pd
import simpletransformers
from simpletransformers.classification import ClassificationModel, ClassificationArgs

import sklearn
from sklearn.metrics import accuracy_score, classification_report, precision_recall_fscore_support
from sklearn.model_selection import train_test_split, KFold

# %%
# mount colab to Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wandb login  # using this requires a Weights & Biases account: https://wandb.ai/login

# %%
# load the heldout dataset
test_wd = pd.read_csv("/content/drive/MyDrive/ModelFolder/HeldoutTestData.csv")  # must be set to the exact path of the dataset

# choose only the 'text' and 'label' columns
test_wd = test_wd.iloc[:, [1, 2]]

# %%
# load the model
model = ClassificationModel(
    'bert',
     '/content/drive/MyDrive/ModelFolder',  # must be set to the exact path of the model folder 
     use_cuda = False)  # use_cuda can be set to 'True' if GPU is available

# %%
# test the model on the heldout dataset
test_result, test_model_outputs, test_wrong_predictions = model.eval_model(test_wd, 
acc = sklearn.metrics.accuracy_score, #  acc = accuracy scores
f1=sklearn.metrics.precision_recall_fscore_support, 
output_dir = '/content/drive/MyDrive')  # set to desired output directory
# Out:
# /usr/local/lib/python3.8/dist-packages/simpletransformers/classification/classification_model.py:1454: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
# ...
# Running Evaluation:   0%|          | 0/61 [00:00<?, ?it/s]
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: lbraedder (teamlaerke). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/content/wandb/run-20221226_093249-u28k1m7p</code>
# Syncing run <strong><a href="https://wandb.ai/teamlaerke/ModelAllDataWeightDecay/runs/u28k1m7p" target="_blank">super-bird-1</a></strong> to <a href="https://wandb.ai/teamlaerke/ModelAllDataWeightDecay" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# ...

# %%
# print results 
print(test_result)  # f1 reports in order precision, recall, f1 and with TD scores before ASD
# Out:
# {'mcc': 0.3876434396250262, 'tp': 156, 'tn': 181, 'fp': 60, 'fn': 90, 'auroc': 0.7146543872077725, 'auprc': 0.7226255284067713, 'acc': 0.6919917864476386, 'f1': (array([0.66789668, 0.72222222]), array([0.75103734, 0.63414634]), array([0.70703125, 0.67532468]), array([241, 246])), 'eval_loss': 0.6277574457106043}
